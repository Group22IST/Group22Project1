# %% [markdown]
# The Uber app has many components that makes it a functional app to use for many users needing to travel without the hassle of chasing down a taxi. There are five tables that describe the overall database design of the app. One of the tables is called Car Data. This table keeps track of the location of the car and the kind of Uber driving options that are assigned to that car. Car Data has a Foreign key DriverID and has a one to one relationship with the corresponding table driver data because one may always be on driven by a single driver. The License Plate number is a secondary key because each license number is unique and has to be recorded and it is associated with the car and its owner. Trip Data is a table that has attributes such as the waiting time. Trip Data also has the foreign keys of DriverID, CustomerID, and Transaction ID. It has a one to one relationship with TransactionID because one trip is only ever associated with one transaction, whereas it has a many to one relationship with driver and customer ID because one user and one driver can only be associated with a trip but customers and drivers can make many trips. Driver Data has attributes, like the driver’s full name and driver rating. The Driver Data Table is associated with the CarID, so that is why it is a primary key. The Customer Table has a first and last name, so it is a secondary key, since it is used again.The transaction data table has the foreign keys CustomerID andDriver ID  foreign keys where it has a one to many relationship because it customers and drivers may got tho=rough many transaction but each transactions can only have one driver and one customer.

# %% [markdown]
# ![Group%20Project%20ERL%20Diagram%20%20%281%29.svg](attachment:Group%20Project%20ERL%20Diagram%20%20%281%29.svg)
